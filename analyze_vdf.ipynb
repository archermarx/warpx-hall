# %%
import yt
import matplotlib.pyplot as plt
import numpy as np
import os
from pathlib import Path
from scipy.constants import c, e as q_e, atomic_mass, m_e

import analysis_utils as utils
import analysis

# %%
m_Xe = atomic_mass * 131.293

# === Module config ===
yt.funcs.mylog.setLevel(50)

# === Matplotlib config ===
font = {"family": "Helvetica", "weight": "normal", "size": 15}
plt.set_loglevel("error")
plt.rc("font", **font)
benchmark_color = "#ffb3b3"
fig_dpi = 200

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Set up some relevant directories
dir = Path("/home/marksta/scratch/jep-2025-revision/g1-dt1-si0-ppc75")
particle_diag_dir = dir / "particle_diags"
output_dir = utils.ensure_directory(dir / "output" / "vdf")
#output_dir = utils.ensure_directory(".")

# %%
ds = analysis.load_last_particle_diag(particle_diag_dir)

# %%
analysis.plot_vdf_2D(ds, 'ions', axis='x', output_dir=output_dir)

# %%
plot_right_vdfs(ds, 'electrons', output_dir)

# %%
vdf_file = "vdf_ions_x.csv"
with open(vdf_file, "r") as fd:
    header = fd.readline()[1:].strip()
    extent = [float(x) for x in header.split(',')]
    
reloaded = np.genfromtxt("vdf_ions_x.csv", delimiter = ",")
print(extent)
# Out:
# [0.0, 2.5, -7.0, 19.5]

# %%
x = 19.29
np.sign(x) * np.ceil(abs(x)* 2)/2
# Out:
# 19.5

# %%
plt.imshow(reloaded, origin = 'lower', extent=extent, aspect='auto')
